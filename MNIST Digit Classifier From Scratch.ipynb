# %% [markdown]
# # MNIST Classification using MLP
# The task at hand involves creating a Multilayer Perceptron (MLP) from the ground up to perform classification on the MNIST digit dataset. This dataset encompasses various handwritten digits, and the ultimate objective is to construct a specialized model capable of accurately recognizing these handwritten digits, essentially resulting in a proficient handwritten digit recognition system.

# %% [markdown]
# # 1. Importing the Libraries

# %%
import numpy as np
import torch
import matplotlib.pylab as plt
import math

import pandas as pd
import torch.nn as nn
import torchvision.datasets as dsets
import torchvision.transforms as transforms
from torch.autograd import Variable
from torch.optim import Adam

from sklearn.metrics import confusion_matrix
import seaborn as sns
from time import time

if torch.cuda.is_available():
  device = torch.device("cude:0")
  print("GPU")
else:
  device = torch.device("cpu")
  print("CPU")
# Out:
# CPU

# %% [markdown]
# # 2. Loading the Data

# %%
train_data = dsets.MNIST(root = './data', train = True, transform = transforms.ToTensor(), target_transform=lambda x : nn.functional.one_hot(torch.tensor([x]),10), download = True)
test_data = dsets.MNIST(root = './data', train = False, transform = transforms.ToTensor(), target_transform=lambda x : nn.functional.one_hot(torch.tensor([x]),10), download = True)

# mnist_train=torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=torchvision.transforms.ToTensor(), target_transform=lambda x : nn.functional.one_hot(torch.tensor([x]),10))
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw

# %%
image,label = train_data[0]
image.shape
# Out:
# torch.Size([1, 28, 28])

# %%
plt.imshow(image[0],cmap='gray')

# %%
# creating batches of 64
batch_size = 64

train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, shuffle=False)

# %%
for i in train_loader:
  img, lbl = i;
  print(lbl.shape)
  break
# Out:
# torch.Size([64, 1, 10])

# %% [markdown]
# # 3. Building the model

# %% [markdown]
# ### Initialising the weights and biases

# %%
#glorot initialisation
def glorot(n_o,n_i):
  M = math.sqrt(6/(n_i+n_o))
  return M

# %%
# defining global variables
W=[torch.Tensor(500,784),torch.Tensor(250, 500),torch.Tensor(100, 250),torch.Tensor(10, 100)]
b=[torch.Tensor(500,1),torch.Tensor(250,1),torch.Tensor(100,1),torch.Tensor(10,1)]

# %%
#initialising weights ad biases
def initialise():
  M1 = glorot(500,784)
  W1 = torch.rand(500, 784) * (2 * M1) - M1
  b1 = torch.zeros((500,1))
  M2 = glorot(250,500)
  W2 = torch.rand(250, 500) * (2 * M2) - M2
  b2 = torch.zeros((250,1))
  M3 = glorot(100,250)
  W3 = torch.rand(100, 250) * (2 * M3) - M3
  b3 = torch.zeros((100,1))
  M4 = glorot(10,100)
  W4 = torch.rand(10, 100) * (2 * M4) - M4
  b4 = torch.zeros((10,1))
  W = [W1,W2,W3,W4]
  b = [b1,b2,b3,b4]
  return W,b

# %% [markdown]
# ### Defining the functions needed for the model

# %%
#defining activation functions
def sigmoid(Z):
  A = 1 / (1 + np.exp(-Z))
  return A

def relu(Z):
  A = np.maximum(0,Z)
  return A

def tanh(Z):
  return torch.tanh(Z)

def softmax(Z):
  A = np.exp(Z) / np.exp(Z).sum().item()
  return A

# %%
relu(torch.tensor([1,2,-3,4]))
# Out:
# tensor([1, 2, 0, 4])

# %%
#defining derivations of activation functions
def sigmoid_derivative(Z):
  return (sigmoid(Z)*(1-sigmoid(Z)))

def relu_derivative(Z):
  num=torch.max(abs(Z)/Z,torch.tensor(0))
  return num

def tanh_derivative(Z):
  return (1-(tanh(Z))**2)

# %%
relu_derivative(torch.tensor([1,2,-3,4]))
# Out:
# tensor([1., 1., 0., 1.])

# %%
#defining the loss function
def cross_entropy_loss(y_pred, y_actual):
  loss=-1*torch.log(y_pred)*y_actual
  return torch.max(loss)

# %%
#defining the forward pass
def forward_pass_sigmoid(X, W, b):
  z1 = X
  a1 = X
  z2 = torch.matmul(W[0], X) + b[0]
  a2 = sigmoid(z2)
  z3 = torch.matmul(W[1], a2) + b[1]
  a3 = sigmoid(z3)
  z4 = torch.matmul(W[2], a3) + b[2]
  a4 = sigmoid(z4)
  z5 = torch.matmul(W[3], a4) + b[3]
  a5 = softmax(z5)
  return [z1,z2,z3,z4,z5],[a1,a2,a3,a4,a5]

# %%
#defining the forward pass for tanh
def forward_pass_tanh(X, W, b):
  z1 = X
  a1 = X
  z2 = torch.matmul(W[0], X) + b[0]
  a2 = tanh(z2)
  z3 = torch.matmul(W[1], a2) + b[1]
  a3 = tanh(z3)
  z4 = torch.matmul(W[2], a3) + b[2]
  a4 = tanh(z4)
  z5 = torch.matmul(W[3], a4) + b[3]
  a5 = softmax(z5)
  return [z1,z2,z3,z4,z5],[a1,a2,a3,a4,a5]

# %%
#defining the forward pass for relu
def forward_pass_relu(X, W, b):
  z1 = X
  a1 = X
  z2 = torch.matmul(W[0], X) + b[0]
  a2 = relu(z2)
  z3 = torch.matmul(W[1], a2) + b[1]
  a3 = relu(z3)
  z4 = torch.matmul(W[2], a3) + b[2]
  a4 = relu(z4)
  z5 = torch.matmul(W[3], a4) + b[3]
  a5 = softmax(z5)
  return [z1,z2,z3,z4,z5],[a1,a2,a3,a4,a5]

# %%
# defining backpropogation for sigmoid activation
def back_prop_sigmoid(W,b,z,a,y_actual):
  dj_dw = [torch.Tensor(500,784),torch.Tensor(250, 500),torch.Tensor(100, 250),torch.Tensor(10, 100)]
  dj_db = [torch.Tensor(500,1),torch.Tensor(250,1),torch.Tensor(100,1),torch.Tensor(10,1)]
  del5 = a[4]-torch.transpose(y_actual,0,1)

  dj_dw[3] = torch.matmul(del5,torch.transpose(a[3],0,1))
  dj_db[3] = del5
  deltemp = del5
  for i in range (3,0,-1):
    deli = torch.matmul(torch.transpose(W[i],0,1),deltemp)*sigmoid_derivative(z[i])
    deltemp = deli
    dj_dw[i-1] = torch.matmul(deli,torch.transpose(a[i-1],0,1))
    dj_db[i-1] = deli

  return dj_dw,dj_db

# %%
# defining backpropogation for tanh activation
def back_prop_tanh(W,b,z,a,y_actual):
  dj_dw = [torch.Tensor(500,784),torch.Tensor(250, 500),torch.Tensor(100, 250),torch.Tensor(10, 100)]
  dj_db = [torch.Tensor(500,1),torch.Tensor(250,1),torch.Tensor(100,1),torch.Tensor(10,1)]
  del5 = a[4]-torch.transpose(y_actual,0,1)

  dj_dw[3] = torch.matmul(del5,torch.transpose(a[3],0,1))
  dj_db[3] = del5
  deltemp = del5
  for i in range (3,0,-1):
    deli = torch.matmul(torch.transpose(W[i],0,1),deltemp)*tanh_derivative(z[i])
    deltemp = deli
    dj_dw[i-1] = torch.matmul(deli,torch.transpose(a[i-1],0,1))
    dj_db[i-1] = deli

  return dj_dw,dj_db

# %%
# defining backpropogation for relu activation
def back_prop_relu(W,b,z,a,y_actual):
  dj_dw = [torch.Tensor(500,784),torch.Tensor(250, 500),torch.Tensor(100, 250),torch.Tensor(10, 100)]
  dj_db = [torch.Tensor(500,1),torch.Tensor(250,1),torch.Tensor(100,1),torch.Tensor(10,1)]
  del5 = a[4]-torch.transpose(y_actual,0,1)

  dj_dw[3] = torch.matmul(del5,torch.transpose(a[3],0,1))
  dj_db[3] = del5
  deltemp = del5
  for i in range (3,0,-1):
    deli = torch.matmul(torch.transpose(W[i],0,1),deltemp)*relu_derivative(z[i])
    deltemp = deli
    dj_dw[i-1] = torch.matmul(deli,torch.transpose(a[i-1],0,1))
    dj_db[i-1] = deli

  return dj_dw,dj_db

# %% [markdown]
# ### Implementing the primary model with sigmoid activation function

# %%
epochs = 15
alpha = 0.01
iter_list=[]
loss_list=[]
iter = 0

W,b = initialise()

for j in range(epochs):
  print("Epoch = ",j)
  for batch in train_loader:
    iter = iter+1
    loss=0
    image,label = batch

    dj_dw1 = 0
    dj_db1 = 0
    dj_dw2 = 0
    dj_db2 = 0
    dj_dw3 = 0
    dj_db3 = 0
    dj_dw4 = 0
    dj_db4 = 0

    for i in range(image.shape[0]):
      z,a = forward_pass_sigmoid(torch.unsqueeze(torch.flatten(image[i]),1), W,b)
      dj_dw,dj_db = back_prop_sigmoid(W,b,z,a,label[i])

      dj_dw1 += dj_dw[0]
      dj_db1 += dj_db[0]
      dj_dw2 += dj_dw[1]
      dj_db2 += dj_db[1]
      dj_dw3 += dj_dw[2]
      dj_db3 += dj_db[2]
      dj_dw4 += dj_dw[3]
      dj_db4 += dj_db[3]
      loss+=(cross_entropy_loss(a[4],torch.transpose(label[i],0,1)))/image.shape[0]

    W[0] -= alpha*dj_dw1/image.shape[0]
    b[0] -= alpha*dj_db1/image.shape[0]
    W[1] -= alpha*dj_dw2/image.shape[0]
    b[1] -= alpha*dj_db2/image.shape[0]
    W[2] -= alpha*dj_dw3/image.shape[0]
    b[2] -= alpha*dj_db3/image.shape[0]
    W[3] -= alpha*dj_dw4/image.shape[0]
    b[3] -= alpha*dj_db4/image.shape[0]

    if (iter%200 == 0 or iter%938 == 0):
      iter_list.append(iter)
      print("Iteration = ",iter)
      loss_list.append(loss)
      print("Loss = ",loss)
# Out:
# Epoch =  0
# Iteration =  200
# Loss =  tensor(2.3060)
# Iteration =  400
# Loss =  tensor(2.2800)
# Iteration =  600
# Loss =  tensor(2.3032)
# Iteration =  800
# Loss =  tensor(2.2937)
# Iteration =  938
# Loss =  tensor(2.3077)
# Epoch =  1
# Iteration =  1000
# Loss =  tensor(2.2912)
# Iteration =  1200
# Loss =  tensor(2.2857)
# Iteration =  1400
# Loss =  tensor(2.2750)
# Iteration =  1600
# Loss =  tensor(2.2865)
# Iteration =  1800
# Loss =  tensor(2.2659)
# Iteration =  1876
# Loss =  tensor(2.2740)
# Epoch =  2
# Iteration =  2000
# Loss =  tensor(2.2787)
# Iteration =  2200
# Loss =  tensor(2.2599)
# Iteration =  2400
# Loss =  tensor(2.2619)
# Iteration =  2600
# Loss =  tensor(2.2664)
# Iteration =  2800
# Loss =  tensor(2.2622)
# Iteration =  2814
# Loss =  tensor(2.2662)
# Epoch =  3
# Iteration =  3000
# Loss =  tensor(2.2577)
# Iteration =  3200
# Loss =  tensor(2.2422)
# Iteration =  3400
# Loss =  tensor(2.2307)
# Iteration =  3600
# Loss =  tensor(2.2567)
# Iteration =  3752
# Loss =  tensor(2.2298)
# Epoch =  4
# Iteration =  3800
# Loss =  tensor(2.2117)
# Iteration =  4000
# Loss =  tensor(2.2108)
# Iteration =  4200
# Loss =  tensor(2.1920)
# Iteration =  4400
# Loss =  tensor(2.1929)
# Iteration =  4600
# Loss =  tensor(2.1365)
# Iteration =  4690
# Loss =  tensor(2.2051)
# Epoch =  5
# Iteration =  4800
# Loss =  tensor(2.0959)
# Iteration =  5000
# Loss =  tensor(2.1527)
# Iteration =  5200
# Loss =  tensor(2.0302)
# Iteration =  5400
# Loss =  tensor(2.0599)
# Iteration =  5600
# Loss =  tensor(2.0277)
# Iteration =  5628
# Loss =  tensor(1.9977)
# Epoch =  6
# Iteration =  5800
# Loss =  tensor(1.9534)
# Iteration =  6000
# Loss =  tensor(1.8289)
# Iteration =  6200
# Loss =  tensor(1.8975)
# Iteration =  6400
# Loss =  tensor(1.8931)
# Iteration =  6566
# Loss =  tensor(1.7454)
# Epoch =  7
# Iteration =  6600
# Loss =  tensor(1.7007)
# Iteration =  6800
# Loss =  tensor(1.6491)
# Iteration =  7000
# Loss =  tensor(1.5868)
# Iteration =  7200
# Loss =  tensor(1.4485)
# Iteration =  7400
# Loss =  tensor(1.4704)
# Iteration =  7504
# Loss =  tensor(1.4373)
# Epoch =  8
# Iteration =  7600
# Loss =  tensor(1.4928)
# Iteration =  7800
# Loss =  tensor(1.3624)
# Iteration =  8000
# Loss =  tensor(1.2266)
# Iteration =  8200
# Loss =  tensor(1.3078)
# Iteration =  8400
# Loss =  tensor(1.1472)
# Iteration =  8442
# Loss =  tensor(1.0806)
# Epoch =  9
# Iteration =  8600
# Loss =  tensor(1.2526)
# Iteration =  8800
# Loss =  tensor(1.1408)
# Iteration =  9000
# Loss =  tensor(1.0461)
# Iteration =  9200
# Loss =  tensor(0.9427)
# Iteration =  9380
# Loss =  tensor(0.9827)
# Epoch =  10
# Iteration =  9400
# Loss =  tensor(0.9287)
# Iteration =  9600
# Loss =  tensor(0.9860)
# Iteration =  9800
# Loss =  tensor(0.8977)
# Iteration =  10000
# Loss =  tensor(0.8970)
# Iteration =  10200
# Loss =  tensor(0.9586)
# Iteration =  10318
# Loss =  tensor(1.0107)
# Epoch =  11
# Iteration =  10400
# Loss =  tensor(0.8748)
# Iteration =  10600
# Loss =  tensor(0.8522)
# Iteration =  10800
# Loss =  tensor(0.8640)
# Iteration =  11000
# Loss =  tensor(0.8422)
# Iteration =  11200
# Loss =  tensor(0.7504)
# Iteration =  11256
# Loss =  tensor(0.9234)
# Epoch =  12
# Iteration =  11400
# Loss =  tensor(0.7655)
# Iteration =  11600
# Loss =  tensor(0.9496)
# Iteration =  11800
# Loss =  tensor(0.8032)
# Iteration =  12000
# Loss =  tensor(0.6747)
# Iteration =  12194
# Loss =  tensor(0.7860)
# Epoch =  13
# Iteration =  12200
# Loss =  tensor(0.6433)
# Iteration =  12400
# Loss =  tensor(0.6983)
# Iteration =  12600
# Loss =  tensor(0.6142)
# Iteration =  12800
# Loss =  tensor(0.7381)
# Iteration =  13000
# Loss =  tensor(0.6746)
# Iteration =  13132
# Loss =  tensor(0.7829)
# Epoch =  14
# Iteration =  13200
# Loss =  tensor(0.8101)
# Iteration =  13400
# Loss =  tensor(0.8326)
# Iteration =  13600
# Loss =  tensor(0.5110)
# Iteration =  13800
# Loss =  tensor(0.7570)
# Iteration =  14000
# Loss =  tensor(0.8136)
# Iteration =  14070
# Loss =  tensor(0.6405)

# %%
#plotting the loss vs iterations
plt.plot(iter_list,loss_list)

plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('Loss vs Iterations')
# Out:
# Text(0.5, 1.0, 'Loss vs Iterations')

# %%
#finding the training accuracy
tra_iter=0
tr_iter=[]
tr_loss=[]
count = 0
for batch in train_loader:
  image, label = batch
  for i in range(image.shape[0]):
    z,a = forward_pass_sigmoid(torch.unsqueeze(torch.flatten(image[i]),1), W,b)
    loss+=(cross_entropy_loss(a[4],torch.transpose(label[i],0,1)))/image.shape[0]
    tra_iter+=1
    if(torch.argmax(label[i]) == torch.argmax(a[4])):
      count+=1

#finding the accuracy of the model on the test data
accuracy = (count/60000)*100
print("Training accuracy of the Model = ",accuracy)
# Out:
# Training accuracy of the Model =  82.02833333333334

# %%
#finding the test accuracy and plotting the confusion matrix
y_pred=[]
y_truth=[]
tes_iter=0
test_iter=[]
test_loss=[]
count = 0
for batch in test_loader:
  image, label = batch
  for i in range(image.shape[0]):
    z,a = forward_pass_sigmoid(torch.unsqueeze(torch.flatten(image[i]),1), W,b)
    loss+=(cross_entropy_loss(a[4],torch.transpose(label[i],0,1)))/image.shape[0]
    tes_iter+=1
    y_pred.append(torch.argmax(a[4]))
    y_truth.append(torch.argmax(label[i]))
    if(torch.argmax(label[i]) == torch.argmax(a[4])):
      count+=1
    if(tes_iter%200==0):
      test_loss.append(loss)
      test_iter.append(tes_iter)

#finding the accuracy of the model on the test data
accuracy = (count/10000)*100
print("Test accuracy of the Model = ",accuracy)

#plotting the confusion matrix
cm=confusion_matrix(y_truth,y_pred)
sns.heatmap(cm,annot=True,fmt='d')
# Out:
# Test accuracy of the Model =  82.35
# <AxesSubplot:>

# %%
#plotting the test loss vs iterations
plt.plot(test_iter,test_loss)
plt.xlabel("Iterations")
plt.ylabel("Test Loss")
plt.title('Test Loss vs Iterations')
plt.show()

# %% [markdown]
# ### Implementing the model with tanh instead of sigmoid

# %%
epochs = 15
alpha = 0.01
iter_list=[]
loss_list=[]
iter = 0

W2,b2 = initialise()

for j in range(epochs):
  print("Epoch = ",j)
  for batch in train_loader:
    iter = iter+1
    loss=0
    image,label = batch

    dj_dw1 = 0
    dj_db1 = 0
    dj_dw2 = 0
    dj_db2 = 0
    dj_dw3 = 0
    dj_db3 = 0
    dj_dw4 = 0
    dj_db4 = 0

    for i in range(image.shape[0]):
      z,a = forward_pass_tanh(torch.unsqueeze(torch.flatten(image[i]),1), W2,b2)
      dj_dw,dj_db = back_prop_tanh(W2,b2,z,a,label[i])

      dj_dw1 += dj_dw[0]
      dj_db1 += dj_db[0]
      dj_dw2 += dj_dw[1]
      dj_db2 += dj_db[1]
      dj_dw3 += dj_dw[2]
      dj_db3 += dj_db[2]
      dj_dw4 += dj_dw[3]
      dj_db4 += dj_db[3]
      loss+=(cross_entropy_loss(a[4],torch.transpose(label[i],0,1)))/image.shape[0]

    W2[0] -= alpha*dj_dw1/image.shape[0]
    b2[0] -= alpha*dj_db1/image.shape[0]
    W2[1] -= alpha*dj_dw2/image.shape[0]
    b2[1] -= alpha*dj_db2/image.shape[0]
    W2[2] -= alpha*dj_dw3/image.shape[0]
    b2[2] -= alpha*dj_db3/image.shape[0]
    W2[3] -= alpha*dj_dw4/image.shape[0]
    b2[3] -= alpha*dj_db4/image.shape[0]

    if (iter%200 == 0 or iter%938 == 0):
      iter_list.append(iter)
      print("Iteration = ",iter)
      loss_list.append(loss)
      print("Loss = ",loss)
# Out:
# Epoch =  0
# Iteration =  200
# Loss =  tensor(0.6382)
# Iteration =  400
# Loss =  tensor(0.5020)
# Iteration =  600
# Loss =  tensor(0.3589)
# Iteration =  800
# Loss =  tensor(0.3454)
# Iteration =  938
# Loss =  tensor(0.2485)
# Epoch =  1
# Iteration =  1000
# Loss =  tensor(0.2347)
# Iteration =  1200
# Loss =  tensor(0.3191)
# Iteration =  1400
# Loss =  tensor(0.2515)
# Iteration =  1600
# Loss =  tensor(0.2248)
# Iteration =  1800
# Loss =  tensor(0.7073)
# Iteration =  1876
# Loss =  tensor(0.2186)
# Epoch =  2
# Iteration =  2000
# Loss =  tensor(0.2670)
# Iteration =  2200
# Loss =  tensor(0.1780)
# Iteration =  2400
# Loss =  tensor(0.3131)
# Iteration =  2600
# Loss =  tensor(0.2132)
# Iteration =  2800
# Loss =  tensor(0.1717)
# Iteration =  2814
# Loss =  tensor(0.2551)
# Epoch =  3
# Iteration =  3000
# Loss =  tensor(0.2375)
# Iteration =  3200
# Loss =  tensor(0.3098)
# Iteration =  3400
# Loss =  tensor(0.2231)
# Iteration =  3600
# Loss =  tensor(0.2475)
# Iteration =  3752
# Loss =  tensor(0.1319)
# Epoch =  4
# Iteration =  3800
# Loss =  tensor(0.3118)
# Iteration =  4000
# Loss =  tensor(0.4142)
# Iteration =  4200
# Loss =  tensor(0.2314)
# Iteration =  4400
# Loss =  tensor(0.2386)
# Iteration =  4600
# Loss =  tensor(0.2600)
# Iteration =  4690
# Loss =  tensor(0.1622)
# Epoch =  5
# Iteration =  4800
# Loss =  tensor(0.1925)
# Iteration =  5000
# Loss =  tensor(0.1539)
# Iteration =  5200
# Loss =  tensor(0.1409)
# Iteration =  5400
# Loss =  tensor(0.2241)
# Iteration =  5600
# Loss =  tensor(0.1436)
# Iteration =  5628
# Loss =  tensor(0.4927)
# Epoch =  6
# Iteration =  5800
# Loss =  tensor(0.2575)
# Iteration =  6000
# Loss =  tensor(0.1662)
# Iteration =  6200
# Loss =  tensor(0.2581)
# Iteration =  6400
# Loss =  tensor(0.0778)
# Iteration =  6566
# Loss =  tensor(0.2618)
# Epoch =  7
# Iteration =  6600
# Loss =  tensor(0.1862)
# Iteration =  6800
# Loss =  tensor(0.3450)
# Iteration =  7000
# Loss =  tensor(0.1763)
# Iteration =  7200
# Loss =  tensor(0.3509)
# Iteration =  7400
# Loss =  tensor(0.1364)
# Iteration =  7504
# Loss =  tensor(0.1618)
# Epoch =  8
# Iteration =  7600
# Loss =  tensor(0.1261)
# Iteration =  7800
# Loss =  tensor(0.3400)
# Iteration =  8000
# Loss =  tensor(0.1891)
# Iteration =  8200
# Loss =  tensor(0.2514)
# Iteration =  8400
# Loss =  tensor(0.0700)
# Iteration =  8442
# Loss =  tensor(0.6200)
# Epoch =  9
# Iteration =  8600
# Loss =  tensor(0.1027)
# Iteration =  8800
# Loss =  tensor(0.2463)
# Iteration =  9000
# Loss =  tensor(0.0990)
# Iteration =  9200
# Loss =  tensor(0.1768)
# Iteration =  9380
# Loss =  tensor(0.3432)
# Epoch =  10
# Iteration =  9400
# Loss =  tensor(0.1303)
# Iteration =  9600
# Loss =  tensor(0.0796)
# Iteration =  9800
# Loss =  tensor(0.2132)
# Iteration =  10000
# Loss =  tensor(0.1854)
# Iteration =  10200
# Loss =  tensor(0.1026)
# Iteration =  10318
# Loss =  tensor(0.1089)
# Epoch =  11
# Iteration =  10400
# Loss =  tensor(0.0570)
# Iteration =  10600
# Loss =  tensor(0.1122)
# Iteration =  10800
# Loss =  tensor(0.1625)
# Iteration =  11000
# Loss =  tensor(0.0862)
# Iteration =  11200
# Loss =  tensor(0.0439)
# Iteration =  11256
# Loss =  tensor(0.5499)
# Epoch =  12
# Iteration =  11400
# Loss =  tensor(0.3201)
# Iteration =  11600
# Loss =  tensor(0.1842)
# Iteration =  11800
# Loss =  tensor(0.1137)
# Iteration =  12000
# Loss =  tensor(0.2099)
# Iteration =  12194
# Loss =  tensor(0.0513)
# Epoch =  13
# Iteration =  12200
# Loss =  tensor(0.0994)
# Iteration =  12400
# Loss =  tensor(0.1213)
# Iteration =  12600
# Loss =  tensor(0.1237)
# Iteration =  12800
# Loss =  tensor(0.1205)
# Iteration =  13000
# Loss =  tensor(0.1063)
# Iteration =  13132
# Loss =  tensor(0.1482)
# Epoch =  14
# Iteration =  13200
# Loss =  tensor(0.1284)
# Iteration =  13400
# Loss =  tensor(0.1890)
# Iteration =  13600
# Loss =  tensor(0.1689)
# Iteration =  13800
# Loss =  tensor(0.0768)
# Iteration =  14000
# Loss =  tensor(0.1182)
# Iteration =  14070
# Loss =  tensor(0.1023)

# %%
#plotting the loss vs iterations
plt.plot(iter_list,loss_list)

plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('Loss vs Iterations')
# Out:
# Text(0.5, 1.0, 'Loss vs Iterations')

# %%
#finding the training accuracy
tra_iter=0
tr_iter=[]
tr_loss=[]
count = 0
for batch in train_loader:
  image, label = batch
  for i in range(image.shape[0]):
    z,a = forward_pass_tanh(torch.unsqueeze(torch.flatten(image[i]),1), W2,b2)
    loss+=(cross_entropy_loss(a[4],torch.transpose(label[i],0,1)))/image.shape[0]
    tra_iter = tra_iter + 1
    y_pred.append(torch.argmax(a[4]))
    y_truth.append(torch.argmax(label[i]))
    if(torch.argmax(label[i]) == torch.argmax(a[4])):
      count+=1

accuracy = (count/60000)*100
print("Training Accuracy of the Model = ",accuracy)
# Out:
# Training Accuracy of the Model =  96.43333333333334

# %%
#finding the test accuracy and plotting the confusion matrix
y_pred=[]
y_truth=[]
tes_iter=0
test_iter=[]
test_loss=[]
count = 0
for batch in test_loader:
  image, label = batch
  for i in range(image.shape[0]):
    z,a = forward_pass_tanh(torch.unsqueeze(torch.flatten(image[i]),1), W2,b2)
    loss+=(cross_entropy_loss(a[4],torch.transpose(label[i],0,1)))/image.shape[0]
    tes_iter+=1
    y_pred.append(torch.argmax(a[4]))
    y_truth.append(torch.argmax(label[i]))
    if(torch.argmax(label[i]) == torch.argmax(a[4])):
      count+=1
    if(tes_iter%200==0):
      test_loss.append(loss)
      test_iter.append(tes_iter)

#finding the accuracy of the model on the test data
accuracy = (count/10000)*100
print("Test Accuracy of the Model = ",accuracy)

#plotting the confusion matrix
cm=confusion_matrix(y_truth,y_pred)
sns.heatmap(cm,annot=True,fmt='d')
# Out:
# Test Accuracy of the Model =  96.03
# <AxesSubplot:>

# %%
#plotting the test loss vs iterations
tes_iter=0
count=0
test_iter=[]
test_loss=[]
for batch in test_loader:
  image, label = batch

  loss=0
  for i in range(0,image.shape[0]):
    z,a = forward_pass_tanh(torch.unsqueeze(torch.flatten(image[i]),1), W2,b2)
    loss+=(cross_entropy_loss(a[4],torch.transpose(label[i],0,1)))/image.shape[0]
    tes_iter+=1
    if(torch.argmax(label[i]) == torch.argmax(a[4])):
      count+=1
    if(tes_iter%200==0):
      test_loss.append(loss)
      test_iter.append(tes_iter)

plt.plot(test_iter,test_loss)
plt.xlabel("Iterations")
plt.ylabel("Test loss")
plt.show()

# %% [markdown]
# ### Implementing the model with ReLU instead of sigmoid

# %%
epochs = 15
alpha = 0.01
iter_list=[]
loss_list=[]
iter = 0

W3,b3 = initialise()

for j in range(epochs):
  print("Epoch = ",j)
  for batch in train_loader:
    iter = iter+1
    loss=0
    image,label = batch

    dj_dw1 = 0
    dj_db1 = 0
    dj_dw2 = 0
    dj_db2 = 0
    dj_dw3 = 0
    dj_db3 = 0
    dj_dw4 = 0
    dj_db4 = 0

    for i in range(image.shape[0]):
      z,a = forward_pass_relu(torch.unsqueeze(torch.flatten(image[i]),1), W3,b3)
      dj_dw,dj_db = back_prop_relu(W3,b3,z,a,label[i])

      dj_dw1 += dj_dw[0]
      dj_db1 += dj_db[0]
      dj_dw2 += dj_dw[1]
      dj_db2 += dj_db[1]
      dj_dw3 += dj_dw[2]
      dj_db3 += dj_db[2]
      dj_dw4 += dj_dw[3]
      dj_db4 += dj_db[3]
      loss+=(cross_entropy_loss(a[4],torch.transpose(label[i],0,1)))/image.shape[0]

    W3[0] -= alpha*dj_dw1/image.shape[0]
    b3[0] -= alpha*dj_db1/image.shape[0]
    W3[1] -= alpha*dj_dw2/image.shape[0]
    b3[1] -= alpha*dj_db2/image.shape[0]
    W3[2] -= alpha*dj_dw3/image.shape[0]
    b3[2] -= alpha*dj_db3/image.shape[0]
    W3[3] -= alpha*dj_dw4/image.shape[0]
    b3[3] -= alpha*dj_db4/image.shape[0]

    if (iter%200 == 0 or iter%938 == 0):
      iter_list.append(iter)
      print("Iteration = ",iter)
      loss_list.append(loss)
      print("Loss = ",loss)
# Out:
# Epoch =  0
# Iteration =  200
# Loss =  tensor(0.9800)
# Iteration =  400
# Loss =  tensor(0.4990)
# Iteration =  600
# Loss =  tensor(0.6155)
# Iteration =  800
# Loss =  tensor(0.4306)
# Iteration =  938
# Loss =  tensor(0.4518)
# Epoch =  1
# Iteration =  1000
# Loss =  tensor(0.4588)
# Iteration =  1200
# Loss =  tensor(0.1906)
# Iteration =  1400
# Loss =  tensor(0.1493)
# Iteration =  1600
# Loss =  tensor(0.1733)
# Iteration =  1800
# Loss =  tensor(0.2500)
# Iteration =  1876
# Loss =  tensor(0.2326)
# Epoch =  2
# Iteration =  2000
# Loss =  tensor(0.1567)
# Iteration =  2200
# Loss =  tensor(0.2567)
# Iteration =  2400
# Loss =  tensor(0.1780)
# Iteration =  2600
# Loss =  tensor(0.2810)
# Iteration =  2800
# Loss =  tensor(0.1145)
# Iteration =  2814
# Loss =  tensor(0.2110)
# Epoch =  3
# Iteration =  3000
# Loss =  tensor(0.1695)
# Iteration =  3200
# Loss =  tensor(0.1442)
# Iteration =  3400
# Loss =  tensor(0.1422)
# Iteration =  3600
# Loss =  tensor(0.3051)
# Iteration =  3752
# Loss =  tensor(0.1837)
# Epoch =  4
# Iteration =  3800
# Loss =  tensor(0.5046)
# Iteration =  4000
# Loss =  tensor(0.2611)
# Iteration =  4200
# Loss =  tensor(0.1223)
# Iteration =  4400
# Loss =  tensor(0.2498)
# Iteration =  4600
# Loss =  tensor(0.0946)
# Iteration =  4690
# Loss =  tensor(0.4172)
# Epoch =  5
# Iteration =  4800
# Loss =  tensor(0.2648)
# Iteration =  5000
# Loss =  tensor(0.2480)
# Iteration =  5200
# Loss =  tensor(0.4688)
# Iteration =  5400
# Loss =  tensor(0.1044)
# Iteration =  5600
# Loss =  tensor(0.0750)
# Iteration =  5628
# Loss =  tensor(0.2411)
# Epoch =  6
# Iteration =  5800
# Loss =  tensor(0.2174)
# Iteration =  6000
# Loss =  tensor(0.0719)
# Iteration =  6200
# Loss =  tensor(0.1259)
# Iteration =  6400
# Loss =  tensor(0.1307)
# Iteration =  6566
# Loss =  tensor(0.0596)
# Epoch =  7
# Iteration =  6600
# Loss =  tensor(0.2267)
# Iteration =  6800
# Loss =  tensor(0.0547)
# Iteration =  7000
# Loss =  tensor(0.1861)
# Iteration =  7200
# Loss =  tensor(0.0452)
# Iteration =  7400
# Loss =  tensor(0.0981)
# Iteration =  7504
# Loss =  tensor(0.3800)
# Epoch =  8
# Iteration =  7600
# Loss =  tensor(0.0698)
# Iteration =  7800
# Loss =  tensor(0.1914)
# Iteration =  8000
# Loss =  tensor(0.1348)
# Iteration =  8200
# Loss =  tensor(0.0498)
# Iteration =  8400
# Loss =  tensor(0.2391)
# Iteration =  8442
# Loss =  tensor(0.0630)
# Epoch =  9
# Iteration =  8600
# Loss =  tensor(0.0944)
# Iteration =  8800
# Loss =  tensor(0.0307)
# Iteration =  9000
# Loss =  tensor(0.1680)
# Iteration =  9200
# Loss =  tensor(0.1167)
# Iteration =  9380
# Loss =  tensor(0.0245)
# Epoch =  10
# Iteration =  9400
# Loss =  tensor(0.1876)
# Iteration =  9600
# Loss =  tensor(0.0537)
# Iteration =  9800
# Loss =  tensor(0.2096)
# Iteration =  10000
# Loss =  tensor(0.0622)
# Iteration =  10200
# Loss =  tensor(0.0765)
# Iteration =  10318
# Loss =  tensor(0.2256)
# Epoch =  11
# Iteration =  10400
# Loss =  tensor(0.0638)
# Iteration =  10600
# Loss =  tensor(0.1776)
# Iteration =  10800
# Loss =  tensor(0.0817)
# Iteration =  11000
# Loss =  tensor(0.0277)
# Iteration =  11200
# Loss =  tensor(0.0449)
# Iteration =  11256
# Loss =  tensor(0.2716)
# Epoch =  12
# Iteration =  11400
# Loss =  tensor(0.0541)
# Iteration =  11600
# Loss =  tensor(0.0853)
# Iteration =  11800
# Loss =  tensor(0.2216)
# Iteration =  12000
# Loss =  tensor(0.0795)
# Iteration =  12194
# Loss =  tensor(0.1561)
# Epoch =  13
# Iteration =  12200
# Loss =  tensor(0.0295)
# Iteration =  12400
# Loss =  tensor(0.0735)
# Iteration =  12600
# Loss =  tensor(0.0466)
# Iteration =  12800
# Loss =  tensor(0.0288)
# Iteration =  13000
# Loss =  tensor(0.0754)
# Iteration =  13132
# Loss =  tensor(0.0258)
# Epoch =  14
# Iteration =  13200
# Loss =  tensor(0.0222)
# Iteration =  13400
# Loss =  tensor(0.0926)
# Iteration =  13600
# Loss =  tensor(0.1546)
# Iteration =  13800
# Loss =  tensor(0.0293)
# Iteration =  14000
# Loss =  tensor(0.0112)
# Iteration =  14070
# Loss =  tensor(0.0783)

# %%
#plotting training loss vs iterations
plt.plot(iter_list,loss_list)

plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('Loss vs Iterations')
# Out:
# Text(0.5, 1.0, 'Loss vs Iterations')

# %%
#finding the training accuracy
tra_iter=0
tr_iter=[]
tr_loss=[]
count = 0
for batch in train_loader:
  image, label = batch
  for i in range(image.shape[0]):
    z,a = forward_pass_relu(torch.unsqueeze(torch.flatten(image[i]),1), W3,b3)
    loss+=(cross_entropy_loss(a[4],torch.transpose(label[i],0,1)))/image.shape[0]
    tra_iter = tra_iter + 1
    y_pred.append(torch.argmax(a[4]))
    y_truth.append(torch.argmax(label[i]))
    if(torch.argmax(label[i]) == torch.argmax(a[4])):
      count+=1

accuracy = (count/60000)*100
print("Training Accuracy of the Model = ",accuracy)
# Out:
# Training Accuracy of the Model =  98.14

# %%
#finding the test accuracy and plotting the confusion matrix
y_pred=[]
y_truth=[]
tes_iter=0
test_iter=[]
test_loss=[]
count = 0
for batch in test_loader:
  image, label = batch
  for i in range(image.shape[0]):
    z,a = forward_pass_relu(torch.unsqueeze(torch.flatten(image[i]),1), W3,b3)
    loss+=(cross_entropy_loss(a[4],torch.transpose(label[i],0,1)))/image.shape[0]
    tes_iter+=1
    y_pred.append(torch.argmax(a[4]))
    y_truth.append(torch.argmax(label[i]))
    if(torch.argmax(label[i]) == torch.argmax(a[4])):
      count+=1
    if(tes_iter%200==0):
      test_loss.append(loss)
      test_iter.append(tes_iter)

#finding the accuracy of the model on the test data
accuracy = (count/10000)*100
print("Test Accuracy of the Model = ",accuracy)

#plotting the confusion matrix
cm=confusion_matrix(y_truth,y_pred)
sns.heatmap(cm,annot=True,fmt='d')
# Out:
# Test Accuracy of the Model =  97.11999999999999
# <AxesSubplot:>

# %%
#plotting the test loss vs iterations
tes_iter=0
count=0
test_iter=[]
test_loss=[]
for batch in test_loader:
  image, label = batch

  loss=0
  for i in range(0,image.shape[0]):
    z,a = forward_pass_relu(torch.unsqueeze(torch.flatten(image[i]),1), W3,b3)
    loss+=(cross_entropy_loss(a[4],torch.transpose(label[i],0,1)))/image.shape[0]
    tes_iter+=1
    if(torch.argmax(label[i]) == torch.argmax(a[4])):
      count+=1
    if(tes_iter%200==0):
      test_loss.append(loss)
      test_iter.append(tes_iter)

plt.plot(test_iter,test_loss)
plt.xlabel("Iterations")
plt.ylabel("Test loss")
plt.show()

# %% [markdown]
# We can see that the ReLU model provides us with the highest accuracy, and we will hence use this to implement our pytorch model

# %% [markdown]
# # Building a model using pytorch

# %% [markdown]
# The model whihc gave us the highest accuracy was the model using the ReLU activation function so let us build a Pytorch Model with the ReLU architecture

# %%
#redefining the input data as we do not want it to be one hot encoded
pytorch_train=dsets.MNIST(root='./data2',train=True, download=True, transform=transforms.ToTensor())
pytorch_test=dsets.MNIST(root='./data',train=False,download=True, transform=transforms.ToTensor())
pytorchtrain_loader = torch.utils.data.DataLoader(pytorch_train, batch_size=batch_size, shuffle=True)
pytorchtest_loader = torch.utils.data.DataLoader(pytorch_test, batch_size=batch_size, shuffle=True)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./data2/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ./data2/MNIST/raw/train-images-idx3-ubyte.gz to ./data2/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./data2/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ./data2/MNIST/raw/train-labels-idx1-ubyte.gz to ./data2/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./data2/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ./data2/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data2/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data2/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ./data2/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data2/MNIST/raw

# %%
#building the model
input_size = 784
hidden_sizes = [500, 250,100]
output_size = 10

model = nn.Sequential(nn.Linear(input_size, hidden_sizes[0]),
                      nn.ReLU(),
                      nn.Linear(hidden_sizes[0], hidden_sizes[1]),
                      nn.ReLU(),
                      nn.Linear(hidden_sizes[1], hidden_sizes[2]),
                      nn.ReLU(),
                      nn.Linear(hidden_sizes[2],output_size))
print(model)


criterion = nn.CrossEntropyLoss()
optimizer = Adam(model.parameters(), lr=0.01)
# Out:
# Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=500, out_features=250, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=250, out_features=100, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
time0 = time()
epochs = 15
iterations=0
iter_val=[]
loss_val=[]
for e in range(epochs):
    running_loss = 0
    for images, labels in pytorchtrain_loader:
        iterations+=1
        # Flatten images into a 784 long vector
        images = images.view(images.shape[0], -1)

        # Training
        optimizer.zero_grad()

        output = model(images)
        loss = criterion(output, labels)

        #backpropogation step
        loss.backward()

        #Optimizes its weights here
        optimizer.step()

        running_loss += loss.item()

        if(iterations%200==0 or iterations%938==0):
          iter_val.append(iterations)
          loss_val.append(running_loss/iterations)
    else:
        print("Epoch {} - Training loss: {}".format(e, running_loss/len(pytorchtrain_loader)))

print("\nTraining Time (in minutes) =",(time()-time0)/60)
# Out:
# Epoch 0 - Training loss: 0.28620433392150124
# Epoch 1 - Training loss: 0.16899713039892647
# Epoch 2 - Training loss: 0.14414458017277995
# Epoch 3 - Training loss: 0.1266340620634305
# Epoch 4 - Training loss: 0.12567824298597333
# Epoch 5 - Training loss: 0.10964325338657667
# Epoch 6 - Training loss: 0.10070946500902232
# Epoch 7 - Training loss: 0.09463194612124964
# Epoch 8 - Training loss: 0.10017700602372698
# Epoch 9 - Training loss: 0.09585479822971407
# Epoch 10 - Training loss: 0.0865085167865674
# Epoch 11 - Training loss: 0.08577269529694134
# Epoch 12 - Training loss: 0.08077545136605242
# Epoch 13 - Training loss: 0.07770108853176763
# Epoch 14 - Training loss: 0.07580126298979867
#
# Training Time (in minutes) = 0.9992064197858175

# %%
#plotting the training loss vs iterations
plt.plot(iter_val,loss_val)
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.show()

# %%
#training acuuracy
correct_count, all_count = 0, 0
for images,labels in pytorchtrain_loader:
  for i in range(len(labels)):
    img = images[i].view(1, 784)
    with torch.no_grad():
        logps = model(img)


    ps = torch.exp(logps)
    probab = list(ps.numpy()[0])
    pred_label = probab.index(max(probab))
    true_label = labels.numpy()[i]
    if(true_label == pred_label):
      correct_count += 1
    all_count += 1

print("Number Of Images Tested =", all_count)
print("\nModel Accuracy =", (correct_count/all_count)*100)
# Out:
# Number Of Images Tested = 60000
#
# Model Accuracy = 98.46833333333333

# %%
#test accuracy
correct_count, all_count = 0, 0
for images,labels in pytorchtest_loader:
  for i in range(len(labels)):
    img = images[i].view(1, 784)
    with torch.no_grad():
        logps = model(img)


    ps = torch.exp(logps)
    probab = list(ps.numpy()[0])
    pred_label = probab.index(max(probab))
    true_label = labels.numpy()[i]
    if(true_label == pred_label):
      correct_count += 1
    all_count += 1

print("Number Of Images Tested =", all_count)
print("\nModel Accuracy =", (correct_count/all_count)*100)
# Out:
# Number Of Images Tested = 10000
#
# Model Accuracy = 97.2

# %%
#for the confusion matrix
y_pred = []
y_true = []

for images, labels in pytorchtrain_loader:
        images = images.view(images.shape[0], -1)
        output = model(images)

        output = (torch.max(torch.exp(output), 1)[1]).data.cpu().numpy()
        y_pred.extend(output)

        labels = labels.data.cpu().numpy()
        y_true.extend(labels)


cf_matrix = confusion_matrix(y_true, y_pred)
sns.heatmap(cf_matrix, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# On comparing the Pytorch model with model from scratch we observe that the convergence to minima occurs faster in the Pytorch model due to Adam optimizer. It takes steps proportional to the rate of change of the gradient itself, making more accurate decisions. The Backpropagation done here is more accurate as it a computerized algorithm. The training error and testing error is also lesser in the Pytorch model, making it the better model

# %% [markdown]
# ### Pytorch Model with regularisation

# %%
#defining the model
model_l2 = nn.Sequential(nn.Linear(input_size, hidden_sizes[0]),
                      nn.ReLU(),
                      nn.Linear(hidden_sizes[0], hidden_sizes[1]),
                      nn.ReLU(),
                      nn.Linear(hidden_sizes[1], hidden_sizes[2]),
                      nn.ReLU(),
                      nn.Linear(hidden_sizes[2],output_size))
print(model_l2)


criterion_l2 = nn.CrossEntropyLoss()
alpha=0.00001 #taking this as the value for regularization constant
optimizer_l2 = Adam(model_l2.parameters(), lr=0.01,weight_decay=alpha)
# Out:
# Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=500, out_features=250, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=250, out_features=100, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
time0 = time()
epochs = 15
iterations=0
iter_val=[]
loss_val=[]
for e in range(epochs):
    running_loss = 0
    for images, labels in pytorchtrain_loader:
        iterations+=1
        # Flatten MNIST images into a 784 long vector
        images = images.view(images.shape[0], -1)

        # Training pass
        optimizer_l2.zero_grad()

        output = model_l2(images)
        loss = criterion_l2(output, labels)

        #This is where the model learns by backpropagating
        loss.backward()

        #And optimizes its weights here
        optimizer_l2.step()

        running_loss += loss.item()

        if(iterations%200==0 or iterations%938==0):
          iter_val.append(iterations)
          loss_val.append(running_loss/iterations)
    else:
        print("Epoch {} - Training loss: {}".format(e, running_loss/len(pytorchtrain_loader)))

print("\nTraining Time (in minutes) =",(time()-time0)/60)
# Out:
# Epoch 0 - Training loss: 0.27385912013790215
# Epoch 1 - Training loss: 0.16392348553222824
# Epoch 2 - Training loss: 0.1431244036494526
# Epoch 3 - Training loss: 0.13612531263953143
# Epoch 4 - Training loss: 0.11645137314507956
# Epoch 5 - Training loss: 0.11594417616665395
# Epoch 6 - Training loss: 0.1141123827889379
# Epoch 7 - Training loss: 0.10243309753103508
# Epoch 8 - Training loss: 0.11447822793348651
# Epoch 9 - Training loss: 0.10645128292121442
# Epoch 10 - Training loss: 0.09063998236094908
# Epoch 11 - Training loss: 0.1017332259548961
# Epoch 12 - Training loss: 0.0920221244391396
# Epoch 13 - Training loss: 0.10078964719161225
# Epoch 14 - Training loss: 0.09073240041435172
#
# Training Time (in minutes) = 1.0441002011299134

# %%
#plotting the training loss vs iterations
plt.plot(iter_val,loss_val)
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.show()

# %%
#training accuracy
correct_count, all_count = 0, 0
for images,labels in pytorchtrain_loader:
  for i in range(len(labels)):
    img = images[i].view(1, 784)
    with torch.no_grad():
        logps = model_l2(img)


    ps = torch.exp(logps)
    probab = list(ps.numpy()[0])
    pred_label = probab.index(max(probab))
    true_label = labels.numpy()[i]
    if(true_label == pred_label):
      correct_count += 1
    all_count += 1

print("Number Of Images Tested =", all_count)
print("\nModel Accuracy =", (correct_count/all_count)*100)
# Out:
# Number Of Images Tested = 60000
#
# Model Accuracy = 98.17666666666666

# %%
# testing accuracy
correct_count, all_count = 0, 0
for images,labels in pytorchtest_loader:
  for i in range(len(labels)):
    img = images[i].view(1, 784)
    with torch.no_grad():
        logps = model_l2(img)


    ps = torch.exp(logps)
    probab = list(ps.numpy()[0])
    pred_label = probab.index(max(probab))
    true_label = labels.numpy()[i]
    if(true_label == pred_label):
      correct_count += 1
    all_count += 1

print("Number Of Images Tested =", all_count)
print("\nModel Accuracy =", (correct_count/all_count)*100)
# Out:
# Number Of Images Tested = 10000
#
# Model Accuracy = 96.93

# %%
y_pred = []
y_true = []

# iterate over test data
for images, labels in pytorchtrain_loader:
        images = images.view(images.shape[0], -1)
        output = model_l2(images) # Feed Network

        output = (torch.max(torch.exp(output), 1)[1]).data.cpu().numpy()
        y_pred.extend(output) # Save Prediction

        labels = labels.data.cpu().numpy()
        y_true.extend(labels) # Save Truth


# Build confusion matrix
cf_matrix = confusion_matrix(y_true, y_pred)
sns.heatmap(cf_matrix, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The Training accuracy of regularized model is lesser than the unregularized as expected and when the regularization parameter was kept too high (alpha>0.01) it resulted in increasing the loss. When it was kept very low (alpha<0.000001) it didnt have much effect. When alpha=0.0001, training accuracy and test accuracy became more close. This was the perfect value for alpha. When there was no regularization difference between training and test accuracy was around 1.4 %. But when regularization was used the difference in accuracy became only 0.8 %

# %% [markdown]
# ## References
# 1. https://pytorch.org/tutorials/beginner/basics/data_tutorial.html
# 2. https://pytorch.org/vision/stable/generated/torchvision.datasets.MNIST.html#torchvision.datasets.MNIST
# 3. https://youtu.be/cQMt7XqeD4M
# 4. https://pytorch.org/docs/stable/generated/torch.nn.functional.one_hot.html
# 5. https://pytorch.org/docs/stable/nn.init.html
# 6. https://discuss.pytorch.org/t/iterating-through-a-dataloader-object/25437
# 7. https://medium.com/@aungkyawmyint_26195/multi-layer-perceptron-mnist-pytorch-463f795b897a
